# %%
# !python manage.py runserver 0.0.0.0:8000

# %%
docker run -d \
  -p 8000:8000 \
  -v "$(pwd)/media:/app/media" \
  -v "$(pwd)/db.sqlite3:/app/db.sqlite3" \
  --name my-backend-run \
  lab_test_backend:latest
